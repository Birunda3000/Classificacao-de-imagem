# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import utils_img_rec as ut

import pathlib
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras import layers, models, utils

import pickle
inicio = time.time()

print("TF version:", tf.__version__)
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# TF version: 2.9.0
# GPU is available
# 2022-06-26 22:48:31.059414: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-26 22:48:31.076676: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-26 22:48:31.076987: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %% [markdown]
# ## Definindo Variaveis

# %%
BATCH_SIZE = 5000
EPOCHS = 10
IMG_SIZE = 32
numero_de_canais = 3
teste_treino = True
patience = 10
save_model = True

DATA_DIR = '../_DATA_/image/pickle/cifar10-train-pickle.pickle'

TEST_DIR = '../_DATA_/image/pickle/cifar10-test-pickle.pickle'

caminho_modelo = '../modelos_salvos/tensorflow/'
nome = 'modelo_cifar10'+'-EPOCHS='+str(EPOCHS)

DATA_DIR = pathlib.Path(DATA_DIR)
TEST_DIR = pathlib.Path(TEST_DIR)

# %% [markdown]
# ## Lendo e preparando os dados

# %%
pickle_in = open(DATA_DIR,"rb")
data_train = pickle.load(pickle_in)

# %%
if teste_treino:
    pickle_in = open(TEST_DIR,"rb")
    data_test = pickle.load(pickle_in)

# %%
CATEGORIES = ut.get_classes(data_train)
CATEGORIES.sort()
try:
    CATEGORIES.remove('.ipynb_checkpoints')
except:
    pass
print(CATEGORIES)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# ## Exibindo amostra dos dados de treino

# %%
plt.figure(figsize=(10,10))
m = 70
if( len(data_train) < 70 ):
    m = len(data_train)
for i in range(m):
    plt.subplot(7,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(data_train[i][0], cmap='gray')
    plt.xlabel("{}\n({})".format( data_train[i][1] , data_train[i][2] ), color='white')    
plt.show()

# %% [markdown]
# ## Processo de aumento da base

# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
sys.path.insert(1, '../Image-Augmentation/')

import Aug
import utils

# %%
pipe = Aug.Pipe()

pipe.add(Aug.Color(prob=0.6, min_factor=-3, max_factor=3))
pipe.add(Aug.Random_Erasing(prob=0.3, rectangle_area=0.3, repetitions=4))
pipe.add(Aug.Rotacao(prob=0.5, max_left_rotation=88, max_right_rotation=88, fill='edge'))
pipe.add(Aug.Shift(prob=0.5, horizontal_max=0.4, vertical_max=0.4, randomise=True, fill='nearest'))
pipe.add(Aug.Random_Noise(prob=0.5) )

pipe.print_pipe()
# Out:
# Operações:
# |    Operação    | prob | min_factor | max_factor |
# |     Color      | 0.6  |     -3     |     3      |
#
# | -------------- | prob | min_factor | max_factor |
# |     Brilho     | 0.2  |     -3     |     3      |
#
# | -------------- | prob | rectangle_area | repetitions |
# | Random_Erasing | 0.3  |      0.3       |      4      |
#
# | -------------- | prob | max_left_rotation | max_right_rotation | fill |
# |    Rotacao     | 0.5  |         88        |         88         | edge |
#
# | -------------- | prob | horizontal_max | vertical_max | randomise |   fill  |
# |     Shift      | 0.5  |      0.4       |     0.4      |    True   | nearest |
#
# | -------------- | prob | mode |
# |  Random_Noise  | 0.5  | s&p  |

# %%
data_train = utils.call_thread(data = data_train, pipe_instance = pipe, img_per_thread=5000, image_per_image = 2, salvar_imagens_gerada=False)
# Out:
# Thread 8: Executada com sucesso
# Thread 5: Executada com sucesso
# Thread 9: Executada com sucesso
# Thread 6: Executada com sucesso
# Thread 4: Executada com sucesso
# Thread 1: Executada com sucesso
# Thread 7: Executada com sucesso
# Thread 3: Executada com sucesso
# Thread 0: Executada com sucesso
# Thread 2: Executada com sucesso

# %% [markdown]
# ### OBS: O codigo usado no aumento é parte de uma biblioteca ainda não finalizada
# #### Para mais informações sobre a biblioteca
# * https://github.com/Birunda3000/Image-Augmentation

# %% [markdown]
# ## Exibindo amostra dos dados de treino aumentados

# %%
utils.print_list_img(data_train, limite=40)
# Out:
# Numero imagens - 147274

# %% [markdown]
# ## Separando imagem e label e misturando dados

# %%
train_X, train_y = ut.prep_data(data_train, CATEGORIES, IMG_SIZE, numero_de_canais)
#print("Number of training images: ",len(data_train)
print('Entradas de treino - {} - ({}x{})'.format( train_X.shape[0], train_X.shape[1], train_X.shape[2] ))
# Out:
# Entradas de treino - 147274 - (32x32)

# %%
if teste_treino:
    test_X, test_y = ut.prep_data(data_test, CATEGORIES, IMG_SIZE, numero_de_canais)
    #print("Number of test images: ",len(data_test))
    print('Entradas de teste - {} - ({}x{})'.format( test_X.shape[0], test_X.shape[1], test_X.shape[2] ))
# Out:
# Entradas de teste - 10000 - (32x32)

# %% [markdown]
# ## Exibindo amostra dos dados de teste

# %%
plt.figure(figsize=(10,10))
m = 70
if( len(data_test) < 70 ):
    m = len(data_test)
for i in range(m):
    plt.subplot(7,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(data_test[i][0], cmap='gray')
    plt.xlabel("{}\n({})".format( data_test[i][1] , data_test[i][2] ), color='white')    
plt.show()

# %% [markdown]
# ## Normalizando dados

# %%
train_X=np.array(train_X/255.0)
train_y=np.array(train_y)
if teste_treino:
    test_X=np.array(test_X/255.0)
    test_y=np.array(test_y)

# %% [markdown]
# ## Modelo

# %%
model = models.Sequential()
model.add( layers.Conv2D(filters=3, kernel_size=(8, 8), activation='relu', input_shape=(test_X.shape[1:])))
model.add( layers.MaxPooling2D((2, 2)))

model.add( layers.Dropout(rate=0.2) )

#model.add( layers.Conv2D(filters=16, kernel_size=(4, 4), activation='relu'))
#model.add( layers.MaxPooling2D((2, 2)))

#model.add( layers.Dropout(rate=0.2) )

#model.add( layers.Conv2D(filters=32, kernel_size=(2, 2), activation='relu'))
#model.add( layers.MaxPooling2D((2, 2)))

#model.add( layers.Dropout(rate=0.2) )

model.add( layers.Flatten( ) )

model.add( layers.Dense(2000, activation='relu') )
model.add( layers.Dropout(rate=0.1) )

model.add( layers.Dense(128, activation='relu') )
model.add( layers.Dense(len(CATEGORIES) , activation='softmax') )
# Out:
# 2022-06-26 22:53:32.163149: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-26 22:53:32.163520: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-26 22:53:32.163788: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-26 22:53:33.077736: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-26 22:53:33.078058: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-26 22:53:33.078330: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-26 22:53:33.078547: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 39 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 3GB, pci bus id: 0000:03:00.0, compute capability: 6.1
# 2022-06-26 22:53:33.082955: I tensorflow/stream_executor/cuda/cuda_driver.cc:739] failed to allocate 39.38M (41287680 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory

# %% [markdown]
# ## Realizando o treino

# %%
#opt = tf.keras.optimizers.SGD(
#    learning_rate=0.01, momentum=0.1, nesterov=False, name="SGD")
model.compile(loss='categorical_crossentropy', optimizer='adam',  metrics=['accuracy'])
earlystopper = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=patience, restore_best_weights=True, verbose=0)

if  teste_treino:
    history = model.fit(train_X, train_y, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(test_X, test_y), callbacks=[earlystopper])
else:
    history = model.fit(train_X, train_y, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_split=0.2, callbacks=[earlystopper])
# Out:
# 2022-06-26 22:53:34.011671: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1809702912 exceeds 10% of free system memory.
# 2022-06-26 22:53:45.693817: W tensorflow/core/common_runtime/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.68GiB (rounded to 1809702912)requested by op _EagerConst
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-06-26 22:53:45.693857: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] BFCAllocator dump for GPU_0_bfc
# 2022-06-26 22:53:45.693877: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (256): 	Total Chunks: 15, Chunks in use: 15. 3.8KiB allocated for chunks. 3.8KiB in use in bin. 112B client-requested in use in bin.
# 2022-06-26 22:53:45.693892: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (512): 	Total Chunks: 1, Chunks in use: 1. 512B allocated for chunks. 512B in use in bin. 512B client-requested in use in bin.
# 2022-06-26 22:53:45.693906: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (1024): 	Total Chunks: 2, Chunks in use: 1. 2.5KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2022-06-26 22:53:45.693920: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (2048): 	Total Chunks: 1, Chunks in use: 1. 2.2KiB allocated for chunks. 2.2KiB in use in bin. 2.2KiB client-requested in use in bin.
# 2022-06-26 22:53:45.693934: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (4096): 	Total Chunks: 1, Chunks in use: 1. 5.0KiB allocated for chunks. 5.0KiB in use in bin. 5.0KiB client-requested in use in bin.
# 2022-06-26 22:53:45.693950: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (8192): 	Total Chunks: 2, Chunks in use: 1. 18.0KiB allocated for chunks. 8.0KiB in use in bin. 7.8KiB client-requested in use in bin.
# 2022-06-26 22:53:45.693964: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-26 22:53:45.693977: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-26 22:53:45.693989: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-26 22:53:45.694002: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-26 22:53:45.694014: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-26 22:53:45.694030: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (524288): 	Total Chunks: 1, Chunks in use: 1. 1000.0KiB allocated for chunks. 1000.0KiB in use in bin. 1000.0KiB client-requested in use in bin.
# 2022-06-26 22:53:45.694044: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (1048576): 	Total Chunks: 1, Chunks in use: 0. 1.94MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-26 22:53:45.694058: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (2097152): 	Total Chunks: 2, Chunks in use: 1. 6.95MiB allocated for chunks. 3.30MiB in use in bin. 3.30MiB client-requested in use in bin.
# 2022-06-26 22:53:45.694071: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-26 22:53:45.694084: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-26 22:53:45.694098: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (16777216): 	Total Chunks: 1, Chunks in use: 0. 25.54MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-26 22:53:45.694117: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-26 22:53:45.694130: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-26 22:53:45.694143: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-26 22:53:45.694155: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-06-26 22:53:45.694170: I tensorflow/core/common_runtime/bfc_allocator.cc:1050] Bin for 1.68GiB was 256.00MiB, Chunk State:
# 2022-06-26 22:53:45.694183: I tensorflow/core/common_runtime/bfc_allocator.cc:1063] Next region of size 37158912
# 2022-06-26 22:53:45.694201: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30000000 of size 256 next 1
# 2022-06-26 22:53:45.694213: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30000100 of size 1280 next 2
# 2022-06-26 22:53:45.694225: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30000600 of size 256 next 3
# 2022-06-26 22:53:45.694236: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30000700 of size 256 next 4
# 2022-06-26 22:53:45.694248: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30000800 of size 256 next 5
# 2022-06-26 22:53:45.694259: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30000900 of size 256 next 6
# 2022-06-26 22:53:45.694270: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30000a00 of size 256 next 9
# 2022-06-26 22:53:45.694281: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30000b00 of size 256 next 10
# 2022-06-26 22:53:45.694292: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30000c00 of size 256 next 14
# 2022-06-26 22:53:45.694303: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30000d00 of size 256 next 15
# 2022-06-26 22:53:45.694316: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30000e00 of size 512 next 16
# 2022-06-26 22:53:45.694327: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30001000 of size 256 next 19
# 2022-06-26 22:53:45.694339: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30001100 of size 256 next 20
# 2022-06-26 22:53:45.694350: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30001200 of size 256 next 21
# 2022-06-26 22:53:45.694361: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30001300 of size 256 next 24
# 2022-06-26 22:53:45.694372: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30001400 of size 256 next 25
# 2022-06-26 22:53:45.694384: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30001500 of size 256 next 26
# 2022-06-26 22:53:45.694395: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 7f0b30001600 of size 1280 next 7
# 2022-06-26 22:53:45.694406: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30001b00 of size 2304 next 8
# 2022-06-26 22:53:45.694418: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30002400 of size 8192 next 11
# 2022-06-26 22:53:45.694429: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 7f0b30004400 of size 10240 next 23
# 2022-06-26 22:53:45.694441: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30006c00 of size 5120 next 22
# 2022-06-26 22:53:45.694453: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 7f0b30008000 of size 2032640 next 18
# 2022-06-26 22:53:45.694466: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b301f8400 of size 1024000 next 17
# 2022-06-26 22:53:45.694478: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 7f0b302f2400 of size 3831808 next 13
# 2022-06-26 22:53:45.694489: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f0b30699c00 of size 3456000 next 12
# 2022-06-26 22:53:45.694501: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 7f0b309e5800 of size 26781696 next 18446744073709551615
# 2022-06-26 22:53:45.694512: I tensorflow/core/common_runtime/bfc_allocator.cc:1088]      Summary of in-use Chunks by size:
# 2022-06-26 22:53:45.694527: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 15 Chunks of size 256 totalling 3.8KiB
# 2022-06-26 22:53:45.694540: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 512 totalling 512B
# 2022-06-26 22:53:45.694553: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 1280 totalling 1.2KiB
# 2022-06-26 22:53:45.694566: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 2304 totalling 2.2KiB
# 2022-06-26 22:53:45.694579: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 5120 totalling 5.0KiB
# 2022-06-26 22:53:45.694592: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 8192 totalling 8.0KiB
# 2022-06-26 22:53:45.694605: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 1024000 totalling 1000.0KiB
# 2022-06-26 22:53:45.694619: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 3456000 totalling 3.30MiB
# 2022-06-26 22:53:45.694631: I tensorflow/core/common_runtime/bfc_allocator.cc:1095] Sum Total of in-use chunks: 4.29MiB
# 2022-06-26 22:53:45.694643: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] total_region_allocated_bytes_: 37158912 memory_limit_: 41287680 available bytes: 4128768 curr_region_allocation_bytes_: 82575360
# 2022-06-26 22:53:45.694660: I tensorflow/core/common_runtime/bfc_allocator.cc:1103] Stats:
# Limit:                        41287680
# InUse:                         4501248
# MaxInUse:                     10373376
# NumAllocs:                          34
# MaxAllocSize:                  3456000
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-06-26 22:53:45.694675: W tensorflow/core/common_runtime/bfc_allocator.cc:491] *____****_________**********________________________________________________________________________
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /tmp/ipykernel_345170/1162601333.py in <module>
#       5
#       6 if  teste_treino:
# ----> 7     history = model.fit(train_X, train_y, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(test_X, test_y), callbacks=[earlystopper])
#       8 else:
#       9     history = model.fit(train_X, train_y, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_split=0.2, callbacks=[earlystopper])
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     100       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101   ctx.ensure_initialized()
# --> 102   return ops.EagerTensor(value, ctx.device_name, dtype)
#     103
#     104
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %% [markdown]
# ## Grafico do treino

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.45, 1])
plt.legend(loc='lower right')

# %%
print('Tempo de execução: ', time.time() - inicio)

# %%
if save_model:
    loss, acc = model.evaluate(np.concatenate((train_X, test_X)), np.concatenate((train_y, test_y)), verbose=1)
    nome_saida = caminho_modelo+nome+' AUG - acc = '+   str(round(acc, 5))  + ' exec_time - '+ str( round(time.time() - inicio, 4) )  + '.h5'
    model.save(nome_saida)
    print('Salvo como: ',nome_saida)
